# %%
import nasdaqdatalink
import os
import json
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import pandas_market_calendars as mcal
from datetime import datetime

#store my API key
with open('C:/Users/meich/.nasdaq/data_link_apikey.json') as f:
    data=json.load(f)
    key=data['api_key']
quandl.ApiConfig.api_key = key

# %% [markdown]
# ### Retail Trader Activity

# %%
# get historic values, process data
df = pd.read_csv('NDAQ_RTAT_12_5_22.csv')
df.dropna(inplace=True)

# %% [markdown]
# ### Feature Creation

# %%
#ticker based window metrics
window = df.set_index('date').sort_index().groupby('ticker').rolling(3).mean()

# %%
window[window.index.get_level_values(0) =='FSLR']
# Out:
#                    activity  sentiment
# ticker date
# FSLR   2016-01-04       NaN        NaN
#        2016-01-05       NaN        NaN
#        2016-01-06  0.002000        NaN
#        2016-01-07  0.002200        NaN
#        2016-01-08  0.001267        NaN
# ...                     ...        ...
#        2022-11-28  0.000833  -3.333333
#        2022-11-29  0.000867  -4.000000
#        2022-11-30  0.000800  -4.333333
#        2022-12-01  0.000633  -3.333333
#        2022-12-02  0.000667  -0.666667
#
# [1743 rows x 2 columns]

# %%
#daily market wide metrics
avgsent = df.groupby('date').mean()['sentiment']
stdsent = df.groupby('date').std()['sentiment']
stdact = df.groupby('date').std()['activity']

# %%
# sector/industry market wide metrics (after getting equities bundle)

# %%
#create a metric that incorporates sentiment and activity
#right now it's more driven by activity
# activity itself seems like it could be a good predictor of price drop
df['product_sentiment_activity'] = (df['activity']+.00001)*df['sentiment']*100

# %%
df[df['date']>'2021-01-01'].sort_values('product_sentiment_activity',ascending=False).head(20)
# Out:
#                 date ticker  activity  sentiment  product_sentiment_activity
# 893809    2021-06-02    AMC    0.2615        3.0                      78.453
# 910452    2021-05-28    AMC    0.1783        4.0                      71.324
# 1480112   2021-02-19   PLTR    0.0354       19.0                      67.279
# 53793     2021-10-22   DWAC    0.0587       11.0                      64.581
# 62298     2021-10-21   DWAC    0.0662        9.0                      59.589
# 11147360  2022-02-03     FB    0.1107        5.0                      55.355
# 918724    2021-05-27    AMC    0.1360        4.0                      54.404
# 902120    2021-06-01    AMC    0.1213        4.0                      48.524
# 885947    2021-06-03     BB    0.0493        9.0                      44.379
# 885563    2021-06-03    AMC    0.2202        2.0                      44.042
# 1587117   2021-01-29   AAPL    0.0705        6.0                      42.306
# ...

# %%
stock = df[df['ticker'] == 'AMC'].copy()
fig = px.line(stock,x='date',
              y='activity')
fig.show()
# Out:
# <div>                            <div id="06823c45-d12b-4a9e-bad7-cb1de6f847a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06823c45-d12b-4a9e-bad7-cb1de6f847a7")) {                    Plotly.newPlot(                        "06823c45-d12b-4a9e-bad7-cb1de6f847a7",                        [{"hovertemplate":"date=%{x}<br>activity=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2021-11-01","2021-10-29","2021-10-28","2021-10-27","2021-10-26","2021-10-25","2021-10-22","2021-10-21","2021-10-20","2021-10-19","2021-10-18","2021-10-15","2021-10-14","2021-10-13","2021-10-12","2021-10-11","2021-10-08","2021-10-07","2021-10-06","2021-10-05","2021-10-
# ...

# %%
# CHECK FOR AUTO CORRELATION IN BOTH METRICS

# %%
# CREATE POTENTIALLY USEFUL WINDOW FEATURES

# %% [markdown]
# ### Start with a simple model -- Retail Activity Predictors & FWD Select Into

# %%
# BUILD SIMPLE BASELINE MODEL TO PREDICT PRICE AT DIFFERENT TIME POINTS (EX: 5 DAY, 10 DAY, 20 DAY, 1 MONTH, 3 MONTH, 6 MONTH)
#       OR COULD CONSTRUCT AS A CLASSIFICATION MODEL TOO - PREDICT PROBABILITY THAT Y WILL FALL Y%

# %%
# BUILD MODEL TO PREDICT STOCK PRICES
#    START THIS ONE WITH JUST SHORT INTEREST AND RETAIL TRADING ACTIVITY AND BUILD FROM THERE

# %%
# get daily values - figure out how to limit to last recorded data 
nyse = mcal.get_calendar('NYSE')
lastdate = datetime.today().date() - pd.tseries.offsets.CustomBusinessDay(1, holidays = nyse.holidays().holidays)

RTAT = quandl.get_table('NDAQ/RTAT',date=lastdate,
                         paginate=True)

RTAT[RTAT['activity']>0].sort_values('sentiment',ascending=False).head(20)
